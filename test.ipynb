# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # Heeloo
# - 1
# - 2
# - 3

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25])
mylabels = ["Males", "Female", ]
colors = ["red","hotpink"]
plt.pie(y, labels = mylabels,colors=colors)
plt.legend(title = "Gender")
plt.show()
